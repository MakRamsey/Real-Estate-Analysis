# %%
# Import appropriate dependencies
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from scipy.stats import linregress
import time

# Establish proper filepath to csv file
filepath = "Resources/real_estate.csv"

# Read csv file into initial dataframe and display
initial_dataset_df = pd.read_csv(filepath)
initial_dataset_df
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="bac7542a-99df-4c08-8c63-6942b8e00a09" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#rename 'state' as STATE and 'zip_code' as ZIP
initial_dataset_df = initial_dataset_df.rename(columns={'city':'CITY', 'state':'STATE', 'zip_code':'ZIP'})
initial_dataset_df                                               

# find the highest price by state


#price_by_state = initial_dataset_df.groupby(['STATE'])['price'].max()
#price_by_state
# Out:
#            status   price  bed  bath  acre_lot         CITY          STATE  \
# 0        for_sale  525000    3     3      0.45       Agawam  Massachusetts
# 1        for_sale  289900    3     2      0.36       Agawam  Massachusetts
# 2        for_sale  384900    3     2      0.46       Agawam  Massachusetts
# 3        for_sale  199999    3     2      1.76       Agawam  Massachusetts
# 4        for_sale  419000    4     2      2.00       Pelham  Massachusetts
# ...           ...     ...  ...   ...       ...          ...            ...
# 1048570      sold  520000    3     3      0.09      Newberg         Oregon
# 1048571      sold  635000    5     3      0.14    Beaverton         Oregon
# 1048572      sold  749000    4     2      0.20  Wilsonville         Oregon
# 1048573      sold  485000    3     2      0.13      Newberg         Oregon
# 1048574      sold  163312    2     1      0.34        Amity         Oregon
#
#            ZIP  house_size prev_sold_date
# ...

# %%
# Establish proper filepath to csv file
filepath_2 = "Resources/Public_Schools.csv"

# Read csv file into initial dataframe and display
schools_df = pd.read_csv(filepath_2)
schools_df
# Out:
#                    X             Y  OBJECTID        NCESID  \
# 0      -9.844095e+06  5.230976e+06         1  170330000017
# 1      -9.007027e+06  4.195442e+06         2  370297001287
# 2      -9.580426e+06  4.792069e+06         3  180369000584
# 3      -1.243297e+07  3.927588e+06         4   40187003479
# 4      -1.243258e+07  3.924831e+06         5   40187003483
# ...              ...           ...       ...           ...
# 102329 -1.075152e+07  5.688108e+06    102330  270015003019
# 102330 -1.031719e+07  4.598066e+06    102331  290699000174
# 102331 -8.512030e+06  4.450964e+06    102332  510264001238
# 102332 -9.024169e+06  4.580376e+06    102333  540030000182
# 102333 -1.345981e+07  4.856354e+06    102334   69110211706
#
#                                                  NAME             ADDRESS  \
# 0                            ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                              WESTERLY HILLS ACADEMY     4420 DENVER AVE
# ...

# %%
schools_df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'NCESID', 'NAME', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'LEVEL_', 'ENROLLMENT', 'ST_GRADE', 'END_GRADE',
#        'DISTRICTID', 'FT_TEACHER', 'SHELTER_ID'],
#       dtype='object')

# %%
schools_df = schools_df[['NAME', 'CITY', 'STATE', 'ZIP', 'TYPE', 'POPULATION', 'COUNTY', 'LATITUDE', 'LONGITUDE']]
schools_df
# Out:
#                                                  NAME          CITY STATE  \
# 0                            ALDEN-HEBRON HIGH SCHOOL        HEBRON    IL
# 1                              WESTERLY HILLS ACADEMY     CHARLOTTE    NC
# 2                         NORTHWOOD ELEMENTARY SCHOOL      FRANKLIN    IN
# 3       DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL   QUEEN CREEK    AZ
# 4                     DR. CAMILLE CASTEEL HIGH SCHOOL   QUEEN CREEK    AZ
# ...                                               ...           ...   ...
# 102329                          LISMORE COLONY SCHOOL       CLINTON    MN
# 102330                              OSAGE BEACH ELEM.   OSAGE BEACH    MO
# 102331                POINT OPTION ALTERNATIVE SCHOOL  NEWPORT NEWS    VA
# 102332                            GATEWOOD ELEMENTARY  FAYETTEVILLE    WV
# 102333                      PLUMAS COUNTY OPPORTUNITY        QUINCY    CA
#
#           ZIP  TYPE  POPULATION        COUNTY   LATITUDE   LONGITUDE
# ...

# %%
merged_1 = pd.merge(initial_dataset_df, schools_df, how='right', on=['STATE'])
merged_1
# Out:
#        status  price  bed  bath  acre_lot CITY_x STATE  ZIP_x  house_size  \
# 0         NaN    NaN  NaN   NaN       NaN    NaN    IL    NaN         NaN
# 1         NaN    NaN  NaN   NaN       NaN    NaN    NC    NaN         NaN
# 2         NaN    NaN  NaN   NaN       NaN    NaN    IN    NaN         NaN
# 3         NaN    NaN  NaN   NaN       NaN    NaN    AZ    NaN         NaN
# 4         NaN    NaN  NaN   NaN       NaN    NaN    AZ    NaN         NaN
# ...       ...    ...  ...   ...       ...    ...   ...    ...         ...
# 102329    NaN    NaN  NaN   NaN       NaN    NaN    MN    NaN         NaN
# 102330    NaN    NaN  NaN   NaN       NaN    NaN    MO    NaN         NaN
# 102331    NaN    NaN  NaN   NaN       NaN    NaN    VA    NaN         NaN
# 102332    NaN    NaN  NaN   NaN       NaN    NaN    WV    NaN         NaN
# 102333    NaN    NaN  NaN   NaN       NaN    NaN    CA    NaN         NaN
#
#        prev_sold_date                                           NAME  \
# ...

# %%
merged_1_pennsylvania = merged_1.loc[merged_1['STATE'] == '
